# %% [markdown]
# <a href="https://colab.research.google.com/github/mylenatuponi/grafico-dispersao/blob/main/grafico-linhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar de bibliotecas
import random
import matplotlib.pyplot as plt

#Gerar uma lista com 10 números aleatórios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

#Exibir a lista gerada
print("Lista de dados:", dados)

#Plotar os dados
plt.plot(dados, marker='o') #marcador em cada ponto para melhor visualização
plt.title("Gráfico de Dispersão")
plt.xlabel("Índice")
plt.ylabel("Valor")
plt.grid(True)
plt.show()
# Out:
# Lista de dados: [63, 100, 69, 7, 16, 31, 33, 4, 4, 49]
